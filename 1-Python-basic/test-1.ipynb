# %%
print("Hello World")
# Out:
# Hello World

# %%
1+1
# Out:
# 2

# %%
print("Goodbye World")
# Out:
# Goodbye World

# %%
name="Nikhil"
Name="Nikhil"
print(name)
print(Name)
# Out:
# Nikhil
# Nikhil

# %%
#valid variable names
username="Nikhil"
total_count=100
calculate_Sum=()
_data=100
_private_var=100

# %%
#invalid variable names
2nd_name="Nikhil" #start with digit
my-var="test" #contains hyphen
class="A" #python reserved keyword

# %%
#indentation
age=int(input("Enter your age: "))
if age>18:
    print("you are an adult")
else:
    print("you are a minor")
# Out:
# you are an adult

# %%
#line continuation
total_sum=1+2+3+4+5+6+7+ \
4+5+6
print(total_sum)
# Out:
# 43

# %%
#multiple statements in a single line
x=10;y=20;z=30;a=x+y
print(x,y,z)
print(a)
print(type(x))
# Out:
# 10 20 30
# 30
# <class 'int'>

# %%
name="Nikhil"

print(type(name))
# Out:
# <class 'str'>

# %%
#type inference
#Dynamic type in action python variable dont't have fixed type the same
# variable name points to different object with different types
variable=10
print(type(variable))
variable="Now I'm a string"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #name error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
if True:
    print("This is True")
    if False:
        print("This is False")
    print("This will print")
print("outside if block")
# Out:
# This is True
# This will print
# outside if block

# %% [markdown]
# # Variable

# %%
# defining a variable
age=32
height=5.8
name="Nikhil"
is_student=True

print("age: ",age)
print("height: ",height)
print("Name: ",name)
print("Is Student: ",   is_student)
# Out:
# age:  32
# height:  5.8
# Name:  Nikhil
# Is Student:  True

# %%
#naming convestions
## variable name should be descriptive and meaningful
# they always start with letter or underscore
# they can contain letters,numbers,and underscore within inside but not start with number
# variable are case sensitive

# %%
first_name="Nikhil"
last_name="Rathod"

# %%
# Invalid variable names
#2age=30
#first-name="Nikhil"
##@name="nikhil"

# %%
# variable type
# python is dunamically type
#type of variable is determined at runtime

# %%
#type checking and conversion
age=30
print(type(age))

age_str=str(age)
print(type(age_str))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age='25'
print(type(age))
# Out:
# <class 'str'>

# %%
age_int=int(age)
print(type(age_int))
# Out:
# <class 'int'>

# %%
# it is not possible to convert a non-numeric string to integer
name="Nikhil"
int_name=int(name)
print(int_name)
print(type(int_name))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 name="Nikhil"
# ----> 2 int_name=int(name)
#       3 print(int_name)
#       4 print(type(int_name))
#
# ValueError: invalid literal for int() with base 10: 'Nikhil'

# %%
height=5.8
int_height=int(height)
print(type(int_height))

float_height=float(height)
print(type(float_height))
# Out:
# <class 'int'>
# <class 'float'>

# %%
#Dynamic Typing
## Python allows the type of a vraible to change as the program executes
var=10
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
#input
age=int(input("Enter your age: "))
print("You entered: ",age)
print(type(age))
# Out:
# You entered:  25
# <class 'int'>

# %%
num1=float(input("Enter num1: "))
num2=float(input("Enter num2: "))

sum=num1+num2
diff=num1-num2
product=num1*num2
div=num1/num2


print("sum: ",sum)
print("Difference: ",diff)
print("Product: ",product)
print("Division: ",div)
# Out:
# sum:  4.0
# Difference:  0.0
# Product:  4.0
# Division:  1.0

# %%
result="Hello" + 5
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 result="Hello" + 5
#       2 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
new_result="Hello"+" "+"World"
print(new_result)
# Out:
# Hello World

# %%
result1="Hello"+ " "+str(5)
print(result1)
# Out:
# Hello 5

# %%
str1="Hello"
