# %% [markdown]
# #### Positive-negative

# %%
num=int(input("Enter the number: "))
if num==0:
    print("number is zero")
elif num>0:
    print("number is positive")
else:
    print("number is negative")
# Out:
# number is zero

# %%
num1=int(input("Enter the number"))
result= "positive" if num>0 else "neagtive" if num<0 else "Zero"
print(result)
# Out:
# Zero

# %% [markdown]
# ### Even or Odd

# %%
'''number=int(input("Enter the number: "))
if number%2==0:
    print("Even")
else:
    print("False")'''

num=4
"Even" if  num%2==0 else "odd"
# Out:
# 'Even'

# %% [markdown]
# ### sum of first n natural number

# %%
'''num=int(input("Enter the number: "))
sum=0
for i in range(num+1):
    sum+=i
print(sum)'''

#num=8
#(num*(num+1))/2

# recursion
# calling phase does not give any output
# During function calls → no output yet
# During return → actual values are computed
def getSum(num):
    if num==1:
        return 1
    return num+getSum(num-1)
num=8
print(getSum(num))
# Out:
# 36
